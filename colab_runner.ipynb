# %% [markdown]
# # Multi-Horizon OFI: Colab GitHub Runner
#
# Run this cell in Google Colab to automatically:
# 1. Clone/Pull your latest code from GitHub.
# 2. Mount Google Drive to access datasets and save model checkpoints.
# 3. Resume/start training.
#
# **Note:** Replace `https://github.com/your-username/multi-horizon-ofi.git` with your actual repository URL.

# %%
import os

# 1. Clone or pull the latest code from GitHub
REPO_URL = "https://github.com/your-username/multi-horizon-ofi.git"
if not os.path.exists("/content/multi-horizon-ofi"):
    # !git clone $REPO_URL /content/multi-horizon-ofi
# %cd /content/multi-horizon-ofi
# !git pull origin main

# 2. Mount Google Drive for data and weights
from google.colab import drive
drive.mount('/content/drive', force_remount=False)

# 3. Run the master training script
# Add --test at the end of the line below to run a fast nuked 1-epoch test
# !python scripts/run_training.py
