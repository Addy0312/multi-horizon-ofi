# %% [markdown]
# # Multi-Horizon OFI: Colab Runner
#
# Run this cell in Google Colab to automatically mount your drive and resume/start training.
# Because the codebase is modular, you **do not** need to copy-paste code changes here.
# Just edit the Python files locally, let Google Drive sync them, and run this cell!

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=False)

# Ensure you are in the project root directory
# %cd /content/drive/MyDrive/multi-horizon-ofi

# Run the master training script
# !python scripts/run_training.py
